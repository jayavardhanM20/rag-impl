# %%
# !pip install transformers datasets torch sentence-transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 6.3 MB/s eta 0:00:0000:01
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.3.1

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ## Chunk and Index data into DB ##

# %%
from nltk.tokenize import sent_tokenize
from transformers import AutoTokenizer

from datasets import load_dataset
datasets = ['hagrid', 'hotpotqa', 'msmarco']

retrieval_model = "BAAI/LLM-Embedder"
# retrieval_model = "sentence-transformers/all-miniLM-L6-v2"

tokenizer = AutoTokenizer.from_pretrained(retrieval_model)

TOKEN_LIMIT = 512
SLIDING_WINDOW_OVERLAP = 100

# Function for chunking with token limit and sliding window
def chunk_with_token_limit(text, token_limit, overlap):
    sentences = sent_tokenize(text)  # Split text into sentences
    chunks = []  # Store resulting chunks
    current_chunk = []  # Temporarily hold sentences for the current chunk
    current_chunk_tokens = 0  # Token count for the current chunk

    for sentence in sentences:
        # Tokenize the sentence and calculate its token count
        sentence_tokens = tokenizer.tokenize(sentence)
        num_tokens = len(sentence_tokens)

        # print(f"Tokens: {sentence_tokens[0]}")

        # If adding this sentence exceeds the token limit
        if current_chunk_tokens + num_tokens > token_limit:
            # Save the current chunk
            chunk_text = " ".join(current_chunk)
            chunks.append(chunk_text)

            # Prepare the next chunk with overlap
            overlap_tokens = tokenizer.tokenize(" ".join(current_chunk[-1:]))
            current_chunk = [sentence for sentence in current_chunk[-(overlap // len(overlap_tokens)) :]] if current_chunk else []
            current_chunk_tokens = sum(len(tokenizer.tokenize(sent)) for sent in current_chunk)

        # Add the sentence to the current chunk
        current_chunk.append(sentence)
        current_chunk_tokens += num_tokens

    # Add the last chunk if it exists
    if current_chunk:
        chunk_text = " ".join(current_chunk)
        chunks.append(chunk_text)

    return chunks

def process_document_with_identifiers(document):
    processed_data = []
    title_count = -1  # to start from 0
    # print("document>>>>>>>",document)
    for section in document:
        section_chunks = []
        passage_count = [ord('a')]  # Passage identifier as a list to handle nested increments
        title_count += 1  # Increment title count

        # Tokenize the section into sentences
        sentences = sent_tokenize(section)
        for sentence in sentences:
            if sentence.startswith("Title:"):
                # New document detected
                identifier = f"{title_count}{''.join(chr(c) for c in passage_count)}"  # Identifier for the title
                chunked_texts = chunk_with_token_limit(sentence, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)
                for chunk in chunked_texts:
                    section_chunks.append([identifier, chunk])
                passage_count = [ord('a')]  # Reset passage count for the new document
            else:
                # Sentence under the current document
                identifier = f"{title_count}{''.join(chr(c) for c in passage_count)}"
                chunked_texts = chunk_with_token_limit(sentence, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)
                #print("chunked_texts>>>>process_document_with_identifiers>>>>> "+ "".join(chunked_texts))
                for chunk in chunked_texts:
                    section_chunks.append([identifier, chunk])

                # Increment passage_count intelligently
                i = len(passage_count) - 1
                while i >= 0:
                    passage_count[i] += 1
                    if passage_count[i] > ord('z'):
                        passage_count[i] = ord('a')
                        if i == 0:
                            passage_count.insert(0, ord('a'))  # Add a new character to the identifier
                        i -= 1
                    else:
                        break


        # print("section_chunks>>>>>>>",section_chunks)
        processed_data.append(section_chunks)

    return processed_data
# Out:
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# ## **Check uniqueness of data before insertion** ##

# %%
import hashlib

# Function to generate a hash based on content and key metadata
def generate_hash(content, metadata):
    """Generate a unique hash for the document content and key metadata."""
    key_fields = f"{content}|{metadata.get('item_index')}|{metadata.get('prefix')}"
    return hashlib.md5(key_fields.encode('utf-8')).hexdigest()

# Function to retrieve existing hashes from the database
def get_existing_hashes(collection):
    """Retrieve all existing hashes (IDs) currently in the database."""
    all_records = collection.get(include=["documents", "metadatas"])  # Fetch documents and metadata
    existing_hashes = set()
    for doc, metadata in zip(all_records["documents"], all_records["metadatas"]):
        doc_hash = generate_hash(doc, metadata)
        existing_hashes.add(doc_hash)
    return existing_hashes

# Function to retrieve existing hashes from the database
def get_existing_hashes_milvus(all_records):
    """Retrieve all existing hashes (IDs) currently in the database."""
    existing_hashes = set()
    print(f"all records >>> {len(all_records)}")    
    if all_records == None or len(all_records) == 0:
        return existing_hashes
        
    for doc, metadata in zip(all_records["documents"], all_records["metadata"]):
        doc_hash = generate_hash(doc, metadata)
        existing_hashes.add(doc_hash)
    return existing_hashes

# %% [markdown]
# ## Store and retrieve data from Milvus** ##

# %%
# !pip install pymilvus pymilvus[model]
# Out:
# Collecting pymilvus
#   Downloading pymilvus-2.5.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (71.0.4)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (1.64.1)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (3.20.3)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from pymilvus)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.1.4)
# Collecting milvus-lite>=2.4.0 (from pymilvus)
#   Downloading milvus_lite-2.4.11-py3-none-manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting milvus-model>=0.1.0 (from pymilvus[model])
#   Downloading milvus_model-0.2.11-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from milvus-lite>=2.4.0->pymilvus) (4.66.5)
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.10/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (4.44.2)
# Collecting onnxruntime (from milvus-model>=0.1.0->pymilvus[model])
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.19.1)
# Collecting coloredlogs (from onnxruntime->milvus-model>=0.1.0->pymilvus[model])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (4.12.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->milvus-model>=0.1.0->pymilvus[model])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.3.0)
# Downloading pymilvus-2.5.2-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 6.9 MB/s eta 0:00:00
# Downloading milvus_lite-2.4.11-py3-none-manylinux2014_x86_64.whl (45.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 MB 40.0 MB/s eta 0:00:00:00:0100:01
# Downloading milvus_model-0.2.11-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 80.9 MB/s eta 0:00:00:00:0100:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: python-dotenv, milvus-lite, humanfriendly, coloredlogs, pymilvus, onnxruntime, milvus-model
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 milvus-lite-2.4.11 milvus-model-0.2.11 onnxruntime-1.20.1 pymilvus-2.5.2 python-dotenv-1.0.1

# %%
import time
import numpy as np
from pymilvus import connections
from pymilvus import FieldSchema, CollectionSchema, DataType, Collection
from pymilvus import MilvusClient
from pymilvus import utility

class VectorDataStore:
    db_url = "http://localhost:19530"
    #description = f"collection created for {self.name}"

    def __init__(self, path="/content/ragbench.db"):
        self.client = MilvusClient(path)



    def create_collection(self, name, vec_dim=128):
        if self.client.has_collection(name):
            self.default_collection_name = name

        self.description = f"collection to store {name}"

        index_params = self.client.prepare_index_params()
        index_params.add_index(
            field_name="embedding",
            index_type="AUTOINDEX",
            # params={
            #     "M": 16, # Number of bidirectional links created for each element
            #     "efConstruction": 200 # Size of the dynamic list for the nearest neighbours during indexing
            # },
            metric_type="COSINE"
        )
        schema = self.client.create_schema(
            auto_id=False,
            enable_dynamic_fields=True,
        )
        schema.add_field(field_name="pk", datatype=DataType.VARCHAR, max_length=64, is_primary=True)
        schema.add_field(field_name="metadata", datatype=DataType.JSON)
        schema.add_field(field_name="documents", datatype=DataType.VARCHAR, max_length=512)
        schema.add_field(field_name="embedding", datatype=DataType.FLOAT_VECTOR, dim=vec_dim)
        schema.add_field(field_name="timestamp", datatype=DataType.INT64)
        
        collection = self.client.create_collection(collection_name=name,
                                       schema=schema,
                                       index_params=index_params)
        self.current_collection = collection
        return collection


    def get_collection(self, name):
        if not self.client.has_collection(name):
            raise ValueError(f"Collection '{name}' does not exist.")
        self.current_collection = Collection(name)
        return self.current_collection

    def get_all_records(self, collection):
        all_records = self.client.query(
            collection_name=collection,
            filter=None,
            output_fields=["documents", "metadata"],
            limit=10000
        )
        if all_records == None:
            all_records = []

        return all_records

    def has_entities(self, name):
        if not self.client.has_collection(name):
            raise ValueError(f"Collection '{name}' does not exists.")
        self.default_collection = name
        collection_stats = self.client.get_collection_stats(collection_name)
        count = collection_stats.get("row_count", 0)  # Retrieve the number of entities
        return count

    def insert(self, collection_name: str, metadata: list[dict[str, any]],
                documents: list[str], embeddings: np.ndarray, ids: list[int]):

        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist. Create it first.")

        if len(metadata) != len(embeddings) != len(documents) != len(ids):
           raise ValueError("Metadata, documnets, ids and embeddings must have the same length.")

        data = []
        for meta, doc, emb, id in zip(metadata, documents, embeddings, ids):
          datum = {
              "pk": id,
              "metadata": meta,
              "documents": doc,
              "embedding": emb.tolist(),
              "timestamp": int(time.time()),
          }
          data.append(datum)

        self.client.insert(collection_name, data)
        print(f"Inserted {len(metadata)} records into collection '{collection_name}'.")

    def drop_collection(self, collection_name: str):
        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist.")
        self.client.drop_collection(collection_name)
        print(f"Dropped collection '{collection_name}'.")

    def delete_all(self, collection_name: str):
        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist.")
        self.client.delete(collection_name, expr="pk >= 0")
        self.client.flush([collection_name])

    def search(self, query_embedding: np.ndarray, top_k: int = 10) -> list[dict[str, any]]:
        """
        Search across all collections for the top-k closest embeddings.
        :param query_embedding: The embedding vector to search for.
        :param top_k: Number of top results to retrieve.
        :return: A list of dictionaries containing collection name, id, metadata, and distance.
        """
        results = []
        #collections = self.client.list_collections()
        collections = ["ragbench_collection_techqa_v09"]
        start_time = time.time()
        for collection_name in collections:
            if not self.client.has_collection(collection_name):
                continue

            # Set params to COSINE to match chromadb
            search_params = {
                "metric_type": "COSINE", 
                "params": {
                    "ef": 64
                }
            }

            search_results = self.client.search(
                collection_name=collection_name,
                data=[query_embedding],
                anns_field="embedding",
                search_params=search_params,
                limit=top_k,
                output_fields=["metadata", "documents"]
            )

            for hits in search_results:
                for hit in hits:
                    print(f"Collection: {collection_name}, data: {str(hit)}")
                    results.append({
                        "collection": collection_name,
                        "id": hit["id"],
                        "metadata": hit["entity"]["metadata"],
                        "distance": hit["distance"],
                        "documents": hit["entity"]["documents"]
                      })

        results = sorted(results, key=lambda x: x["distance"])[:top_k]
        end_time = time.time()
        print(f"Search completed. Found {len(results)} results. in {end_time - start_time} secs")
        return results

    def extract_documents(self, search_results: list[dict[str, any]]) -> list[np.ndarray]:
      """
      Extract embedding values from search results.
      :param search_results: List of dictionaries containing search results.
      :return: List of embedding vectors as NumPy arrays.
      """
      return [np.array(result["documents"]) for result in search_results if "documents" in result]

# %%
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

datasets = ['hagrid', 'hotpotqa', 'msmarco']

all_documents = []
all_ids = []
all_metadatas = []

# Process each dataset
doc_idx = 0  # Global document index for unique IDs
for dataset in datasets:
    data = load_dataset("rungalileo/ragbench", dataset, split="train")
    # #only select first 5 records for debugging duplicate records. **PLEASE REMOVE THIS AFTER DEBUGGING**
    # data = data.select(range(2))
    for idx, row in tqdm(enumerate(data), desc=f"Processing {dataset}"):
        # Extract document text
        doc_text = row.get('documents', '')

        # Skip if no documents found
        if not doc_text:
            continue

        # Process the document
        processed_output = process_document_with_identifiers(doc_text)
        added_item_idxs = set()

        # Populate the lists
        for section_idx, section in enumerate(processed_output):
            for item_idx, (prefix, content) in enumerate(section):
                # Skip if this item_idx has already been processed
                if item_idx in added_item_idxs:
                    continue

                # Add the item_idx to the set to track it
                added_item_idxs.add(item_idx)

                # Add the document
                document = f"[{prefix}] {content}"
                all_documents.append(document)

                # Construct a globally unique ID
                doc_id = f"{dataset}_{doc_idx}_{section_idx}_{item_idx}"
                all_ids.append(doc_id)

                # Construct metadata
                metadata = {
                    "dataset": dataset,
                    "global_index": doc_idx,
                    "section_index": section_idx,
                    "item_index": item_idx,
                    "prefix": prefix,
                    "type": "Title" if prefix.endswith("a") else "Passage",
                }
                all_metadatas.append(metadata)

        doc_idx += 1  # Increment global document index

# Step 4: Generate Embeddings
#embedder = SentenceTransformer(retrieval_model)  # Pretrained sentence transformer
embedder = SentenceTransformer(retrieval_model)  # Pretrained sentence transformer
batch_size = 2500  # Adjust based on available memory

# Generate embeddings in batches
all_embeddings = []
for i in tqdm(range(0, len(all_documents), batch_size), desc="Generating embeddings"):
    batch_docs = all_documents[i:i + batch_size]
    batch_embeddings = embedder.encode(batch_docs, show_progress_bar=True)
    all_embeddings.extend(batch_embeddings)
# Out:
# README.md:   0%|          | 0.00/24.7k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/9.42M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.97M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2892 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/322 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1318 [00:00<?, ? examples/s]
# Processing hagrid: 2892it [00:10, 269.97it/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/6.37M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.45M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1883 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/390 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/424 [00:00<?, ? examples/s]
# Processing hotpotqa: 1883it [00:07, 259.50it/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/9.13M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/2.00M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1870 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/423 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/397 [00:00<?, ? examples/s]
# Processing msmarco: 1870it [00:13, 136.80it/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Generating embeddings:   0%|          | 0/18 [00:00<?, ?it/s]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:   6%|▌         | 1/18 [00:06<01:53,  6.65s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  11%|█         | 2/18 [00:12<01:40,  6.25s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  17%|█▋        | 3/18 [00:18<01:30,  6.03s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  22%|██▏       | 4/18 [00:24<01:23,  5.96s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  28%|██▊       | 5/18 [00:30<01:18,  6.06s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  33%|███▎      | 6/18 [00:36<01:12,  6.06s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  39%|███▉      | 7/18 [00:42<01:07,  6.11s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  44%|████▍     | 8/18 [00:48<01:01,  6.12s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  50%|█████     | 9/18 [00:55<00:55,  6.13s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  56%|█████▌    | 10/18 [01:01<00:49,  6.16s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  61%|██████    | 11/18 [01:07<00:44,  6.32s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  67%|██████▋   | 12/18 [01:14<00:37,  6.31s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  72%|███████▏  | 13/18 [01:19<00:30,  6.08s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  78%|███████▊  | 14/18 [01:24<00:23,  5.80s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  83%|████████▎ | 15/18 [01:30<00:16,  5.61s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  89%|████████▉ | 16/18 [01:35<00:11,  5.52s/it]
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Generating embeddings:  94%|█████████▍| 17/18 [01:40<00:05,  5.52s/it]
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# Generating embeddings: 100%|██████████| 18/18 [01:43<00:00,  5.74s/it]

# %%
collection_name = "ragbench_hhm_v1"
datastor = VectorDataStore()

insert_data = False
store_client = "Milvus"
num_records = 0

if datastor.client.has_collection(collection_name):
  num_records = datastor.has_entities(collection_name)
  if num_records == 0:
    insert_data = True
else:
  datastor.create_collection(collection_name, embedder.get_sentence_embedding_dimension())
  insert_data = True

print(f"count >>> {num_records} insert_data >>> {insert_data}")
# Out:
# count >>> 0 insert_data >>> True

# %%
# Adding data to Milvus with enhanced duplicate check
if not insert_data:
    existing_hashes = set()
else:
    existing_hashes = get_existing_hashes_milvus(datastor.get_all_records(collection_name))

for i in tqdm(range(0, len(all_documents), batch_size), desc="Adding data to Milvus"):
    batch_embeddings = all_embeddings[i:i + batch_size]
    batch_metadatas = all_metadatas[i:i + batch_size]
    batch_documents = all_documents[i:i + batch_size]
    batch_ids = []

    # Generate hashes for each document in the batch
    for doc, metadata in zip(batch_documents, batch_metadatas):
        doc_hash = generate_hash(doc, metadata)
        if doc_hash not in existing_hashes:
            batch_ids.append(doc_hash)
            existing_hashes.add(doc_hash)  # Add hash to local set to avoid duplicates in the same batch
        else:
            print(f"Skipping duplicate document: {doc[:50]}...")  # Print a preview of the duplicate doc

    # Add non-duplicate documents to the database
    if batch_ids:  # Ensure there are non-duplicate documents to add
        # Add the batch to the Milvus collection
        if store_client == "Milvus" and insert_data:
            datastor.insert(collection_name,
                metadata=batch_metadatas,
                documents=batch_documents,
                embeddings=np.array(batch_embeddings),
                ids=batch_ids
            )
# Out:
# all records >>> 0
# Adding data to Milvus:   0%|          | 0/18 [00:00<?, ?it/s]
# Skipping duplicate document: [0a] The Worst Witch is a series of children's boo...
# Skipping duplicate document: [0b] The series are primarily boarding school and ...
# Skipping duplicate document: [0c] The first one, "The Worst Witch", was publish...
# Skipping duplicate document: [0d] The books have become some of the most succes...
# Skipping duplicate document: [0a] Organophosphate pesticides are one of the top...
# Skipping duplicate document: [1b] Organophosphates are used as insecticides, me...
# Skipping duplicate document: [1c] Symptoms include increased saliva and tear pr...
# Skipping duplicate document: [1d] While onset of symptoms is often within minut...
# Skipping duplicate document: [1e] Symptoms can last for days to weeks....
# Skipping duplicate document: [1f] Organophosphate poisoning occurs most commonl...
# Skipping duplicate document: [1g] Exposure can be from drinking, breathing in t...
# Skipping duplicate document: [1h] The underlying mechanism involves the inhibit...
# Skipping duplicate document: [1i] Diagnosis is typically based on the symptoms ...
# Skipping duplicate document: [1j] Carbamate poisoning can present similarly....
# Skipping duplicate document: [1k] Prevention includes banning very toxic types ...
# Skipping duplicate document: [1l] Among those who work with pesticides the use ...
# Skipping duplicate document: [1m] In those who have organophosphate poisoning t...
# Skipping duplicate document: [1n] General measures such as oxygen and intraveno...
# Skipping duplicate document: [1o] Attempts to decontaminate the stomach, with a...
# Skipping duplicate document: [1p] While there is a theoretical risk of health c...
# Skipping duplicate document: [1q] OPs are one of the most common causes of pois...
# Skipping duplicate document: [1r] There are nearly 3 million poisonings per yea...
# Skipping duplicate document: [1s] Around 15% of people who are poisoned die as ...
# Skipping duplicate document: [1t] Organophosphate poisoning has been reported a...
# Skipping duplicate document: [0a] "The Sue Sylvester Shuffle" is the eleventh e...
# Skipping duplicate document: [0b] It was written by Ian Brennan, directed by Br...
# Skipping duplicate document: [0c] In the episode, an effort to dispel student r...
# Skipping duplicate document: [0d] When cheerleading coach Sue Sylvester (Jane L...
# Skipping duplicate document: [2e] Here, viewership registered an increase of ap...
# Skipping duplicate document: [2f] In the UK, the episode was watched by 2.64 mi...
# Skipping duplicate document: [0a] While stationed in southern California, he me...
# Skipping duplicate document: [0b] Thaxter's first role was as Ted Lawson's wife...
# Skipping duplicate document: [0c] They had two children, Susan Schuyler "Skye" ...
# Skipping duplicate document: [0d] The marriage ended in divorce in 1962....
# Skipping duplicate document: [0a] In the 1990s he ascended Popocatepetl in Mexi...
# Skipping duplicate document: [0b] In the summer of 2001, he climbed Elbrus in R...
# Skipping duplicate document: [0c] In the winter of 2002 and 2003, Winkler climb...
# Skipping duplicate document: [1d] The highest peaks of the Americas are located...
# Skipping duplicate document: [2e] It is one of the Seven Summits....
# Skipping duplicate document: [0a] In China, a plea bargaining pilot scheme has ...
# Skipping duplicate document: [0b] For defendants that faces jail terms of three...
# Skipping duplicate document: [1c] After an endorsement by the Chairman National...
# Skipping duplicate document: [1d] If the request for plea bargain is accepted b...
# Skipping duplicate document: [1e] The accused is disqualified to take part in e...
# Skipping duplicate document: [0a] Several historians such as British historian ...
# Skipping duplicate document: [0b] Kitzikis called the Ottoman state "a Greek-Tu...
# Skipping duplicate document: [0c] The American historian Speros Vryonis wrote t...
# Skipping duplicate document: [0d] Other historians have followed the lead of th...
# Skipping duplicate document: [0e] Another group of historians led by the Turkis...
# Skipping duplicate document: [0f] More recently, the American historian Heath L...
# Skipping duplicate document: [1g] The remaining Muslim converts in both elected...
# Skipping duplicate document: [1h] Around this point in time, new European ideas...
# Skipping duplicate document: [1i] As a rule, the Ottomans did not require follo...
# Skipping duplicate document: [1j] Some Muslims in the Balkans chose to leave, w...
# Skipping duplicate document: [1k] This demographic transition can be illustrate...
# Skipping duplicate document: [0a] This minor planet was named after Brontosauru...
# Skipping duplicate document: [0b] Adult individuals measured up to 20 meters an...
# Skipping duplicate document: [0c] Many Fossils have been found in the United St...
# Skipping duplicate document: [0d] Brontosaurus is one of the best-known dinosau...
# Skipping duplicate document: [0e] The official naming citation was published by...
# Skipping duplicate document: [0a] In 1959, Harman Kardon marketed the Citation ...
# Skipping duplicate document: [0b] Designed by Stewart Hegeman, it featured 60 w...
# Skipping duplicate document: [0c] The company promoted their philosophy of desi...
# Skipping duplicate document: [0d] Although the human ear highest audible range ...
# Skipping duplicate document: [0e] These harmonics interact with other frequenci...
# Skipping duplicate document: [0f] Harman Kardon promoted the design in audio ma...
# Skipping duplicate document: [0a] A 2005 review of prior surveys in 46 countrie...
# Skipping duplicate document: [0b] A related figure not given in other studies (...
# Skipping duplicate document: [0c] The prevalence of schizophrenia was consisten...
# Skipping duplicate document: [0a] Grasshoppers eat large quantities of foliage ...
# Skipping duplicate document: [0b] Pasture, grain, forage, vegetable and other c...
# Skipping duplicate document: [0c] Grasshoppers often bask in the sun, and thriv...
# Skipping duplicate document: [0d] A single season of drought is not normally su...
# Skipping duplicate document: [0e] Although sunny weather stimulates growth, the...
# Skipping duplicate document: [0f] This means that although precipitation is nee...
# Skipping duplicate document: [0a] Lanthanum usually occurs together with cerium...
# Skipping duplicate document: [0b] Lanthanum was first found by the Swedish chem...
# Skipping duplicate document: [0c] Although it is classified as a rare earth ele...
# Skipping duplicate document: [0d] In minerals such as monazite and bastnäsite, ...
# Skipping duplicate document: [0e] It is extracted from those minerals by a proc...
# Skipping duplicate document: [2f] He partially decomposed a sample of cerium ni...
# Skipping duplicate document: [2g] Since lanthanum's properties differed only sl...
# Skipping duplicate document: [2h] "to lie hidden")....
# Skipping duplicate document: [2i] Relatively pure lanthanum metal was first iso...
# Skipping duplicate document: [0a] The Pittsburgh Steelers (6–2) have won the mo...
# Skipping duplicate document: [0b] New England has the most Super Bowl appearanc...
# Skipping duplicate document: [0c] The Miami Dolphins (1971–1973) and New Englan...
# Skipping duplicate document: [0d] The Denver Broncos (3–5) and Patriots have ea...
# Skipping duplicate document: [0e] The Minnesota Vikings (0–4) and the Bills hav...
# Skipping duplicate document: [0f] The record for consecutive wins is two and is...
# Skipping duplicate document: [0g] Among those, Dallas (1992–1993; 1995) and New...
# Skipping duplicate document: [0h] The 1972 Dolphins capped off the only perfect...
# Skipping duplicate document: [0i] The only team with multiple Super Bowl appear...
# Skipping duplicate document: [0j] Four current NFL teams have never appeared in...
# Skipping duplicate document: [0a] Currently, the Emperor of Japan is the only h...
# Skipping duplicate document: [0b] The Imperial House of Japan is the oldest con...
# Skipping duplicate document: [0c] The historical origins of the Emperors lie in...
# Skipping duplicate document: [0d] The current Emperor is Akihito....
# Skipping duplicate document: [0e] He acceded to the Chrysanthemum Throne upon t...
# Skipping duplicate document: [0f] The Japanese government announced in December...
# Skipping duplicate document: [0a] The land area of the Commonwealth nations is ...
# Skipping duplicate document: [0b] The three largest Commonwealth nations by are...
# Skipping duplicate document: [0c] In 2016, the Commonwealth members had a combi...
# Skipping duplicate document: [1d] Tuvalu is the smallest member, with about 10,...
# Skipping duplicate document: [0a] He received his Grammy Award for "The Book of...
# Skipping duplicate document: [0b] Lopez is also the first person to have won th...
# Skipping duplicate document: [0c] He is also the first winner to also win the s...
# Skipping duplicate document: [0d] Between 2006 and 2018, Legend received a tota...
# Skipping duplicate document: [0e] Legend has won the most Grammy awards, 10, of...
# Skipping duplicate document: [0f] In addition to being the first black man to a...
# Skipping duplicate document: [0g] Legend, Andrew Lloyd Webber, and Tim Rice all...
# Skipping duplicate document: [0h] Between 1980 and 2018, Lloyd Webber received ...
# Skipping duplicate document: [0i] Between 1980 and 2018, Rice received a total ...
# Skipping duplicate document: [0j] However, in each case, one of these awards ha...
# Skipping duplicate document: [0k] (Streisand has not received a competitive Ton...
# Skipping duplicate document: [0a] In 1989, Nintendo signed a deal with Sony to ...
# Skipping duplicate document: [0b] However, Nintendo broke the agreement and ins...
# Skipping duplicate document: [0c] Witnessing the poor reception of the Sega Meg...
# Skipping duplicate document: [0d] As part of dissolving the agreement with Phil...
# Skipping duplicate document: [1e] Contracting out to independent studios, Phili...
# Skipping duplicate document: [1f] Philips insisted that the development studios...
# Skipping duplicate document: [1g] Because the system had not been designed as a...
# Skipping duplicate document: [6h] In 1992, a deal was reached allowing Sony to ...
# Skipping duplicate document: [0a] Liu was selected for the crew of Shenzhou 9, ...
# Skipping duplicate document: [0b] Liu became the first female Chinese astronaut...
# Skipping duplicate document: [0c] The mission was launched on June 16, 2012, 49...
# Skipping duplicate document: [0d] During this manned space mission, Liu perform...
# Skipping duplicate document: [1e] The first people in space who had never been ...
# Skipping duplicate document: [2f] In addition, a number of other countries — Ca...
# Skipping duplicate document: [0a] The original library was founded by an Act of...
# Skipping duplicate document: [0b] The Act created a Board of Regents for the In...
# Skipping duplicate document: [1c] Smithsonian conservators provide myriad servi...
# Skipping duplicate document: [1d] Founded in 1846 the Smithsonian is the world'...
# Skipping duplicate document: [2e] Other Smithsonian Institution museums and gal...
# Skipping duplicate document: [2f] The Smithsonian American Art Museum and the N...
# Skipping duplicate document: [2g] The Renwick Gallery, which is located in a se...
# Skipping duplicate document: [2h] Other Smithsonian museums and galleries inclu...
# Skipping duplicate document: [0a] María Estela Martínez Cartas de Perón (born 4...
# Skipping duplicate document: [0b] She was the third wife of President Juan Peró...
# Skipping duplicate document: [0c] During her husband's third term as president ...
# Skipping duplicate document: [0d] Following her husband's death in office in 19...
# Skipping duplicate document: [0e] She holds the distinction of having been the ...
# Adding data to Milvus:   6%|▌         | 1/18 [00:02<00:35,  2.08s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0a] Nevertheless, much of Samus' media reception ...
# Skipping duplicate document: [0b] GameTrailers named Samus number one on a 2006...
# Skipping duplicate document: [0c] GameDaily ranked Samus seventh on a list of t...
# Skipping duplicate document: [0d] She was further listed on GameDaily's list of...
# Skipping duplicate document: [0e] In 2008, Spike placed Samus on the top of the...
# Skipping duplicate document: [0f] In 2009, UGO.com ranked Samus as 11th on a li...
# Skipping duplicate document: [0a] Dallas, the third largest city in the U.S. st...
# Skipping duplicate document: [0b] The tallest building in the city is the Bank ...
# Skipping duplicate document: [0c] It also stands as the 3rd-tallest building in...
# Skipping duplicate document: [0d] The second-tallest skyscraper in the city is ...
# Skipping duplicate document: [0e] The Comerica Bank Tower, completed in 1987 an...
# Skipping duplicate document: [0f] Three of the ten tallest buildings in Texas a...
# Skipping duplicate document: [1g] Excluding antennas and spires, the Renaissanc...
# Skipping duplicate document: [0a] In humans, the large intestine begins in the ...
# Skipping duplicate document: [0b] It then continues as the colon ascending the ...
# Skipping duplicate document: [0c] Overall, in humans, the large intestine is ab...
# Skipping duplicate document: [1d] The area of the large intestinal mucosa of an...
# Skipping duplicate document: [0a] Germany has a long heritage of using electrom...
# Skipping duplicate document: [0b] In 1888, Heinrich Hertz, who first demonstrat...
# Skipping duplicate document: [0c] In 1904, Christian Hülsmeyer obtained German ...
# Skipping duplicate document: [0d] With the advent of the radio tube and electro...
# Skipping duplicate document: [0e] In 1933, physicist Rudolf Kühnhold, Scientifi...
# Skipping duplicate document: [0f] For the transmitter, he obtained assistance f...
# Skipping duplicate document: [0g] In January 1934, they formed at Berlin-Obersc...
# Skipping duplicate document: [0a] Sun bears are found in the tropical rainfores...
# Skipping duplicate document: [0b] They now occur very patchily through much of ...
# Skipping duplicate document: [0c] Their current distribution in eastern Myanmar...
# Skipping duplicate document: [0d] The bear’s habitat is associated with tropica...
# Skipping duplicate document: [0e] "Helarctos anmamiticus", described by Pierre ...
# Skipping duplicate document: [0a] The holiday commemorates the events of 29 Oct...
# Skipping duplicate document: [0b] Turkey had "de facto" been a republic since 2...
# Skipping duplicate document: [0c] On 29 October 1923, the status of the nation ...
# Skipping duplicate document: [0d] After that, a vote was held in the Grand Nati...
# Skipping duplicate document: [1e] The Treaty of Lausanne of July 24, 1923, led ...
# Skipping duplicate document: [1f] Mustafa Kemal became the republic's first Pre...
# Skipping duplicate document: [1g] The Ottoman fez was abolished, full rights fo...
# Skipping duplicate document: [1h] According to the Law on Family Names, the Tur...
# Skipping duplicate document: [1i] Turkey was neutral in World War II (1939–45) ...
# Skipping duplicate document: [1j] An invasion was threatened in 1941 but did no...
# Skipping duplicate document: [1k] Germany had been its largest trading partner ...
# Skipping duplicate document: [1l] It purchased arms from both sides....
# Skipping duplicate document: [1m] The Allies tried to stop German purchases of ...
# Skipping duplicate document: [1n] Starting in 1942 the Allies provided military...
# Skipping duplicate document: [1o] The Turkish leaders conferred with Roosevelt ...
# Skipping duplicate document: [1p] By August 1944, with Germany nearing defeat, ...
# Skipping duplicate document: [1q] In February 1945, it declared war on Germany ...
# Skipping duplicate document: [0a] Sidoktaya is one of the oldest ancient towns ...
# Skipping duplicate document: [0b] It is established by Prince Yazakumar (a. Min...
# Skipping duplicate document: [0c] Now it is over 900 years of age....
# Skipping duplicate document: [0d] there are many archaeological places includin...
# Skipping duplicate document: [0e] The ancient city wall had been found buried i...
# Skipping duplicate document: [1f] Like most subsequent cities, the main entranc...
# Skipping duplicate document: [1g] Stupas and monastic buildings have also been ...
# Skipping duplicate document: [0a] According to Michel Tribalat, a researcher at...
# Skipping duplicate document: [0b] Maghrebis have settled mainly in the industri...
# Skipping duplicate document: [0c] Many famous French people like Edith Piaf, Is...
# Skipping duplicate document: [0a] The other meaning of the term "channel" in te...
# Skipping duplicate document: [0b] For example, one radio station can broadcast ...
# Skipping duplicate document: [0c] Each radio station would transmit radio waves...
# Skipping duplicate document: [0d] Each station in this example is separated fro...
# Skipping duplicate document: [0a] The name "Haflinger" comes from the village o...
# Skipping duplicate document: [0b] The breed is also called the Avelignese, from...
# Skipping duplicate document: [0c] Haflingers are always chestnut in color and c...
# Skipping duplicate document: [0d] The mane and tail are white or flaxen....
# Skipping duplicate document: [0e] The height of the breed has increased since t...
# Skipping duplicate document: [0f] The desired height today is between ....
# Skipping duplicate document: [0g] Breeders are discouraged from breeding horses...
# Skipping duplicate document: [0h] The breed has a refined head and light poll....
# Skipping duplicate document: [0i] The neck is of medium length, the withers are...
# Skipping duplicate document: [0j] The back is medium-long and muscular, the cro...
# Skipping duplicate document: [0k] The legs are clean, with broad, flat knees an...
# Skipping duplicate document: [0l] The Haflinger has rhythmic, ground-covering g...
# Skipping duplicate document: [0m] The walk is relaxed but energetic....
# Skipping duplicate document: [0n] The trot and canter are elastic, energetic, a...
# Skipping duplicate document: [0o] There is some knee action, and the canter has...
# Skipping duplicate document: [0p] One important consideration in breeding durin...
# Skipping duplicate document: [0q] A requirement for a quiet, kind nature has be...
# Skipping duplicate document: [0r] Some sources recognize two types of Haflinger...
# Skipping duplicate document: [0s] The Food and Agriculture Organization recogni...
# Skipping duplicate document: [0t] However, all breed organizations recognize an...
# Skipping duplicate document: [0a] A foil is a very thin sheet of metal, usually...
# Skipping duplicate document: [0b] Foils are most easily made with malleable met...
# Skipping duplicate document: [0c] Foils usually bend under their own weight and...
# Skipping duplicate document: [0d] The more malleable a metal, the thinner foil ...
# Skipping duplicate document: [0e] For example, aluminium foil is usually about ...
# Skipping duplicate document: [0f] Extremely thin foil is called metal leaf....
# Skipping duplicate document: [0g] Leaf tears very easily and must be picked up ...
# Skipping duplicate document: [0a] Green Arrow is a fictional superhero who appe...
# Skipping duplicate document: [0b] Created by Mort Weisinger and designed by Geo...
# Skipping duplicate document: [0c] His real name is Oliver Jonas Queen, a wealth...
# Skipping duplicate document: [0d] Sometimes shown dressed like the character Ro...
# Skipping duplicate document: [0e] Though much less frequently used in modern st...
# Skipping duplicate document: [0f] At the time of his debut, Green Arrow functio...
# Skipping duplicate document: [0a] On the morning of September 15, 1898, the reg...
# Skipping duplicate document: [0b] The soldiers said one last good-bye to each o...
# Skipping duplicate document: [0c] Before they all returned to their respective ...
# Skipping duplicate document: [0d] Many of the men were unable to gain their job...
# Skipping duplicate document: [0e] Some, due to illness or injury, were unable t...
# Skipping duplicate document: [0f] Money was donated by a number of wealthier su...
# Skipping duplicate document: [0g] A first reunion of the Rough Riders was held ...
# Skipping duplicate document: [0h] Roosevelt, then Governor of New York, attende...
# Skipping duplicate document: [0i] In 1948, fifty years after the Rough Riders d...
# Skipping duplicate document: [0j] The stamp depicts Captain William Owen "Bucky...
# Skipping duplicate document: [0k] The Rough Riders continued to have annual reu...
# Skipping duplicate document: [0l] He died in 1975....
# Skipping duplicate document: [0a] Trench warfare has become archetypically asso...
# Skipping duplicate document: [0b] By the end of October 1914 the whole front in...
# Skipping duplicate document: [0c] Mass infantry assaults were futile in the fac...
# Skipping duplicate document: [0d] Both sides concentrated on breaking up enemy ...
# Skipping duplicate document: [0e] Trench warfare also took place on other front...
# Skipping duplicate document: [2f] The war would be won by the side that was abl...
# Skipping duplicate document: [0a] Verden (Aller) or Verden an der Aller () is a...
# Skipping duplicate document: [0b] The station was opened in 1847 and is located...
# Skipping duplicate document: [0c] The train services are operated by Deutsche B...
# Skipping duplicate document: [0d] The station has been part of the Bremen S-Bah...
# Skipping duplicate document: [0a] The balance (also balance scale, beam balance...
# Skipping duplicate document: [0b] In its traditional form, it consists of a piv...
# Skipping duplicate document: [0c] The unknown mass is placed in one pan and sta...
# Skipping duplicate document: [0d] In precision balances, a more accurate determ...
# Skipping duplicate document: [0e] Technically, a balance compares weight rather...
# Skipping duplicate document: [0f] g or kg)....
# Skipping duplicate document: [0a] The end of Roman rule in Britain facilitated ...
# Skipping duplicate document: [0b] The Anglo-Saxons, a collection of various Ger...
# Skipping duplicate document: [0c] They introduced the Old English language, whi...
# Skipping duplicate document: [0d] The Anglo-Saxons warred with British successo...
# Skipping duplicate document: [0e] Raids by Vikings became frequent after about ...
# Skipping duplicate document: [0f] During this period, several rulers attempted ...
# Skipping duplicate document: [1g] Tolkien noticed that a subtle distinction pre...
# Skipping duplicate document: [1h] In Old English there is a distinction between...
# Skipping duplicate document: [0a] In Judaism, Heaven is sometimes described as ...
# Skipping duplicate document: [0b] Jews do not believe in "Hell" as a place of e...
# Skipping duplicate document: [0c] Gehenna is a place or condition of purgatory ...
# Skipping duplicate document: [0d] Therefore, some violations like suicide would...
# Skipping duplicate document: [0e] Judaism also does not have a notion of hell a...
# Skipping duplicate document: [3f] Satan is rarely mentioned in Tannaitic litera...
# Skipping duplicate document: [3g] According to a narration, the sound of the sh...
# Skipping duplicate document: [3h] In Hasidic Judaism, the Kabbalah presents Sat...
# Skipping duplicate document: [3i] The Hasidic Jews of the 18th century associat...
# Skipping duplicate document: [0a] While the Poles fought the Swedes, Peter foun...
# Skipping duplicate document: [0b] It was named after his patron saint Saint Pet...
# Skipping duplicate document: [0c] He forbade the building of stone edifices out...
# Skipping duplicate document: [0d] Between 1713 and 1728 and in 1732–1918, Saint...
# Skipping duplicate document: [0a] "Tava" or "sun", is the Ute word that was giv...
# Skipping duplicate document: [0b] The band of Ute people who called the Pikes P...
# Skipping duplicate document: [0c] The Ute people first arrived in Colorado abou...
# Skipping duplicate document: [0d] In the 1800s, when the Arapaho people arrived...
# Skipping duplicate document: [0e] Early Spanish explorers named the mountain ""...
# Skipping duplicate document: [0f] American explorer Zebulon Pike named the moun...
# Skipping duplicate document: [0g] American explorer Stephen Harriman Long named...
# Skipping duplicate document: [0h] The mountain was later renamed "Pike's Peak" ...
# Skipping duplicate document: [0i] The name was simplified to "Pikes Peak" by th...
# Skipping duplicate document: [7j] Ute and other tribes came to the area, spent ...
# Skipping duplicate document: [7k] Artifacts found from the nearby Garden of the...
# Skipping duplicate document: [0a] The President of Iran is the highest official...
# Skipping duplicate document: [0b] Unlike the executive in other countries, the ...
# Skipping duplicate document: [0c] Chapter IX of the Constitution of the Islamic...
# Skipping duplicate document: [0d] The procedures for presidential election and ...
# Skipping duplicate document: [0e] The President functions as the executive of t...
# Skipping duplicate document: [0f] These include signing treaties and other agre...
# Skipping duplicate document: [0g] The President also appoints the ministers, su...
# Skipping duplicate document: [1h] The procedures for presidential election and ...
# Skipping duplicate document: [1i] The President functions as the executive of a...
# Skipping duplicate document: [2j] The Supreme Leader Ali Khamenei directly choo...
# Skipping duplicate document: [2k] Iran’s regional policy is directly controlled...
# Skipping duplicate document: [2l] All of Iran’s ambassadors to Arab countries, ...
# Skipping duplicate document: [0a] The first full-scale thermonuclear test was c...
# Skipping duplicate document: [0b] The design of all modern thermonuclear weapon...
# Skipping duplicate document: [0c] Similar devices were developed by the Soviet ...
# Skipping duplicate document: [0a] On January 18, 2012, The CW green-lit a pilot...
# Skipping duplicate document: [0b] The series, "Arrow", offers a fresh take on t...
# Skipping duplicate document: [0c] In addition to the character's experiences as...
# Skipping duplicate document: [0d] Stephen Amell portrays Oliver Queen in the se...
# Skipping duplicate document: [0e] It premiered in North America on October 10, ...
# Skipping duplicate document: [0f] On April 2, 2018, The CW renewed the series f...
# Skipping duplicate document: [0g] Oliver Queen has made multiple appearances in...
# Skipping duplicate document: [0h] Those series are set in a shared universe cal...
# Skipping duplicate document: [1i] Unlike in the comic books, Queen does not go ...
# Skipping duplicate document: [1j] On January 8, 2017, The CW renewed the show f...
# Skipping duplicate document: [1k] On April 2, 2018, The CW renewed the show for...
# Skipping duplicate document: [1l] In addition to his old enemies seeking reveng...
# Skipping duplicate document: [0a] Commercial banana production in the United St...
# Skipping duplicate document: [0b] While Americans eat of bananas per person per...
# Skipping duplicate document: [0a] In 2015 it was announced that the British-bas...
# Skipping duplicate document: [0b] Upon reopening in 2017, the Hudson became the...
# Skipping duplicate document: [0c] The Tony Awards Administration Committee rule...
# Skipping duplicate document: [0a] In the early 21st century, historian Robert L...
# Skipping duplicate document: [0b] According to the "Encyclopedia of African Ame...
# Skipping duplicate document: [0c] Yellow fever caused the most deaths....
# Skipping duplicate document: [0d] Geggus points out that at least 3 of every 5 ...
# Skipping duplicate document: [0e] There has been considerable debate over wheth...
# Skipping duplicate document: [0a] In the United Kingdom, Parliament consists of...
# Skipping duplicate document: [0b] The House of Commons is composed of 650 (soon...
# Skipping duplicate document: [0c] The leader of a Party that wins more than hal...
# Skipping duplicate document: [0d] The House of Lords is a body of long-serving,...
# Skipping duplicate document: [1e] Until 2009, 12 Lords of Appeal in Ordinary sa...
# Skipping duplicate document: [1f] At present, 786 people sit in the House of Lo...
# Skipping duplicate document: [1g] Membership is not fixed and decreases only on...
# Skipping duplicate document: [0a] Nvidia has announced that the company skipped...
# Skipping duplicate document: [0b] Instead, Nvidia had announced that the newly ...
# Skipping duplicate document: [0a] In 1899, Rubén Darío, who was still legally m...
# Skipping duplicate document: [0b] Francisca was from Navalsauz in the province ...
# Skipping duplicate document: [0c] In April 1900, Darío visited Paris for a seco...
# Skipping duplicate document: [0d] His chronicles about this topic would later b...
# Skipping duplicate document: [1e] In León, he was received as a guest of honor,...
# Skipping duplicate document: [1f] In San Salvador, he was married by law to Raf...
# Skipping duplicate document: [1g] One day after the wedding there was a coup d'...
# Skipping duplicate document: [1h] The coup was mainly engineered by general Car...
# Skipping duplicate document: [0a] Frogs are born with legs that are good for ho...
# Skipping duplicate document: [0b] In comparison, toads have shorter legs, drier...
# Skipping duplicate document: [0c] Most frogs and toads are responsible for cont...
# Skipping duplicate document: [0d] However, the green eyed-tree frog is also a c...
# Skipping duplicate document: [0e] As a tadpole, the frogs mostly consume algae ...
# Skipping duplicate document: [0f] Frogs have a moist and permeable skin layer c...
# Skipping duplicate document: [0g] The layer of mucus that covers them also acts...
# Skipping duplicate document: [0h] The reason frogs have large and protruding ey...
# Skipping duplicate document: [0i] This eye feature allows them to see everythin...
# Skipping duplicate document: [0j] The color scheme of the green-eyed tree frog ...
# Skipping duplicate document: [0k] Frogs with bright colors are alerting predato...
# Skipping duplicate document: [0a] Gridiron football does not operate on a leagu...
# Skipping duplicate document: [0b] Different professional leagues play by very d...
# Skipping duplicate document: [0c] There have been attempts at forming true mino...
# Skipping duplicate document: [0a] From 1798-1800, France and the US waged an un...
# Skipping duplicate document: [0b] The US viewed French ambitions in North Ameri...
# Skipping duplicate document: [0c] For commercial reasons, Napoleon wanted to re...
# Skipping duplicate document: [0d] The March 1802 Treaty of Amiens ended the War...
# Skipping duplicate document: [1e] The problems with the Barbary states had neve...
# Skipping duplicate document: [1f] was captured by the Moors, but then set on fi...
# Skipping duplicate document: [1g] The Marines invaded the "shores of Tripoli" i...
# Skipping duplicate document: [1h] This act was enough to induce the Barbary rul...
# Skipping duplicate document: [1i] Subsequently, the Navy was greatly reduced fo...
# Skipping duplicate document: [1j] This policy proved completely ineffective wit...
# Skipping duplicate document: [0a] The Pittsburgh Steelers (6–2) have won the mo...
# Skipping duplicate document: [0b] New England has the most Super Bowl appearanc...
# Skipping duplicate document: [0c] The Miami Dolphins (1971–1973) and New Englan...
# Skipping duplicate document: [0d] The Denver Broncos (3–5) and Patriots have ea...
# Skipping duplicate document: [0e] The Minnesota Vikings (0–4) and the Bills hav...
# Skipping duplicate document: [0f] The record for consecutive wins is two and is...
# Skipping duplicate document: [0g] Among those, Dallas (1992–1993; 1995) and New...
# Skipping duplicate document: [0h] The 1972 Dolphins capped off the only perfect...
# Skipping duplicate document: [0i] The only team with multiple Super Bowl appear...
# Skipping duplicate document: [0j] Four current NFL teams have never appeared in...
# Skipping duplicate document: [0a] The Netherlands is the 66th most populated co...
# Skipping duplicate document: [1b] The 17,000,000 Dutch men, women and children ...
# Skipping duplicate document: [1c] If only the land area of the provinces, 33,71...
# Skipping duplicate document: [1d] 511 inhabitants per square kilometer were rea...
# Skipping duplicate document: [0a] Anderson-Tawil syndrome affects the heart by ...
# Skipping duplicate document: [0b] This, as in other forms of long QT syndrome, ...
# Skipping duplicate document: [0c] The ventricular tachycardia seen in Anderson-...
# Skipping duplicate document: [0d] The arrhythmias seen in association with the ...
# Skipping duplicate document: [4e] Long QT syndrome may be present at birth or d...
# Skipping duplicate document: [4f] The inherited form may occur by itself or as ...
# Skipping duplicate document: [4g] Onset later in life may result from certain m...
# Skipping duplicate document: [4h] Medications that are implicated include certa...
# Skipping duplicate document: [4i] Diagnosis is based on an electrocardiogram (E...
# Skipping duplicate document: [4j] Management may include avoiding strenuous exe...
# Skipping duplicate document: [4k] For people with LQTS who survive cardiac arre...
# Skipping duplicate document: [4l] With proper treatment this decreases to less ...
# Skipping duplicate document: [4m] Long QT syndrome is estimated to affect 1 in ...
# Skipping duplicate document: [4n] Females are affected more often than males....
# Skipping duplicate document: [4o] Most people with the condition develop sympto...
# Skipping duplicate document: [4p] It is a relatively common cause of sudden dea...
# Skipping duplicate document: [4q] In the United States it results in about 3,50...
# Skipping duplicate document: [4r] The condition was first clearly described in ...
# Skipping duplicate document: [4s] Many people with long QT syndrome have no sig...
# Skipping duplicate document: [4t] Symptoms that do occur are generally caused b...
# Skipping duplicate document: [4u] If the arrhythmia reverts to a normal rhythm ...
# Skipping duplicate document: [4v] These faints may be associated with seizures....
# Skipping duplicate document: [4w] However, if the arrhythmia does not terminate...
# Skipping duplicate document: [0a] Although Mexico gained its independence in Se...
# Skipping duplicate document: [0b] The choice of date to celebrate was problemat...
# Skipping duplicate document: [0c] His short-lived reign from 1821–22 ended when...
# Skipping duplicate document: [0d] This was a rocky start for the new nation, wh...
# Skipping duplicate document: [0e] Celebrations of independence during his reign...
# Skipping duplicate document: [0f] Following his ouster, there were calls to com...
# Skipping duplicate document: [0g] The creation of a committee of powerful men t...
# Skipping duplicate document: [4h] Liberals' aimed at turning indigenous communi...
# Skipping duplicate document: [4i] Mexican conservatives repudiated the liberal ...
# Skipping duplicate document: [4j] In the late nineteenth century, liberal army ...
# Skipping duplicate document: [4k] These exploded in certain areas of Mexico dur...
# Skipping duplicate document: [4l] In the aftermath of the Revolution, the Mexic...
# Skipping duplicate document: [4m] This has proved more difficult than policy pl...
# Skipping duplicate document: [0a] On May 29, 1898, 1060 Rough Riders and 1258 o...
# Skipping duplicate document: [0b] The lot awaited orders for departure from Maj...
# Skipping duplicate document: [0c] Under heavy prompting from Washington D.C., G...
# Skipping duplicate document: [0d] Due to this problem, only eight of the twelve...
# Skipping duplicate document: [0e] Aside from Lieutenant-Colonel Roosevelt's fir...
# Skipping duplicate document: [0f] Approximately one fourth of them who received...
# Skipping duplicate document: [0g] This sent the remaining troops into Cuba with...
# Skipping duplicate document: [0a] The median age upon accession to the presiden...
# Skipping duplicate document: [0b] This is how old Lyndon B. Johnson was at the ...
# Skipping duplicate document: [0c] The youngest person to assume the office was ...
# Skipping duplicate document: [0d] The youngest person to be elected president w...
# Skipping duplicate document: [1e] If however Kennedy was that weak, there stood...
# Skipping duplicate document: [1f] Almost immediately after the polls closed on ...
# Skipping duplicate document: [1g] However, Khrushchev was informed that he was ...
# Skipping duplicate document: [0a] Although concrete had been used on a minor sc...
# Skipping duplicate document: [0b] The first use of concrete by the Romans was i...
# Skipping duplicate document: [0c] Ancient Roman concrete was a mixture of lime ...
# Skipping duplicate document: [0d] The ancient builders placed these ingredients...
# Skipping duplicate document: [0e] The aggregates used were often much larger th...
# Skipping duplicate document: [0a] Violet Parr is a fictional character who appe...
# Skipping duplicate document: [0b] The eldest child of Bob and Helen Parr (Mr....
# Skipping duplicate document: [0c] Incredible and Elastigirl), Violet is born wi...
# Skipping duplicate document: [0d] Voiced by Sarah Vowell, Violet is a shy junio...
# Skipping duplicate document: [0e] Throughout the course of the films, Violet gr...
# Skipping duplicate document: [1f] Vowell also played Fernanda, Theacher "Aunt" ...
# Skipping duplicate document: [2g] Until watching the film for the first time, V...
# Skipping duplicate document: [2h] Despite 14 years separating the releases of t...
# Skipping duplicate document: [2i] Syfy Wire's Heather Mason observed that Vowel...
# Skipping duplicate document: [2j] To-date, the "Incredibles" films remain Vowel...
# Skipping duplicate document: [3k] Additionally, she had also been a long-time f...
# Skipping duplicate document: [3l] Vowell ultimately decided to accept the role ...
# Skipping duplicate document: [3m] Vowell concluded, "I can be that kid....
# Skipping duplicate document: [3n] I was that kid....
# Skipping duplicate document: [3o] I love that archetype of the morose, shy, sma...
# Skipping duplicate document: [0a] On 5 March 1953, at 21:50 EET, Joseph Stalin,...
# Skipping duplicate document: [0b] After four days of national mourning, Stalin ...
# Skipping duplicate document: [0c] Nikita Khrushchev, Georgy Malenkov, Vyachesla...
# Skipping duplicate document: [0a] The wolf pack howls on average for 85 seconds...
# Skipping duplicate document: [0b] It is usually started by a single wolf, after...
# Skipping duplicate document: [0c] The pack leader, the alpha wolf, usually uses...
# Skipping duplicate document: [0d] Although some functions of the howling are st...
# Skipping duplicate document: [0e] Researchers have found a relationship between...
# Skipping duplicate document: [0f] According to Friederike Range, co-director of...
# Skipping duplicate document: [0a] While some Swedish areas had Christian minori...
# Skipping duplicate document: [0b] This left only a modest gap between the Chris...
# Skipping duplicate document: [0c] However, Norse paganism and other pre-Christi...
# Skipping duplicate document: [1d] The period 1050 to 1350 – when the Black Deat...
# Skipping duplicate document: [1e] The Kalmar Union between the Scandinavian cou...
# Skipping duplicate document: [1f] The period 1350 to 1523 – when king Gustav Va...
# Skipping duplicate document: [3g] As a result of the adoption of Christianity b...
# Skipping duplicate document: [3h] Völvas, practitioners of seid, a Scandinavian...
# Skipping duplicate document: [4i] For example, only the strong of faith could d...
# Adding data to Milvus:  11%|█         | 2/18 [00:03<00:29,  1.82s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0a] Rikers Island () is New York City's main jail...
# Skipping duplicate document: [0b] Supposedly named after Abraham Rycken who bou...
# Skipping duplicate document: [0c] The island was originally under in size, but ...
# Skipping duplicate document: [0d] Much of the first stages of expansion was acc...
# Skipping duplicate document: [0e] The island itself is politically part of the ...
# Skipping duplicate document: [0a] Oxygen saturation is the fraction of oxygen-s...
# Skipping duplicate document: [0b] The human body requires and regulates a very ...
# Skipping duplicate document: [0c] Normal blood oxygen levels in humans are cons...
# Skipping duplicate document: [0d] If the level is below 90 percent, it is consi...
# Skipping duplicate document: [0e] Blood oxygen levels below 80 percent may comp...
# Skipping duplicate document: [0f] Continued low oxygen levels may lead to respi...
# Skipping duplicate document: [0g] Oxygen therapy may be used to assist in raisi...
# Skipping duplicate document: [0h] Oxygenation occurs when oxygen molecules () e...
# Skipping duplicate document: [0i] For example, blood is oxygenated in the lungs...
# Skipping duplicate document: [0j] Oxygenation is commonly used to refer to medi...
# Skipping duplicate document: [0a] During game broadcasts, WEEI-FM is also made ...
# Skipping duplicate document: [0b] The entire 162-game Red Sox schedule also may...
# Skipping duplicate document: [0c] Many of the smaller stations have always aire...
# Skipping duplicate document: [1d] The primary English-language announcers are J...
# Skipping duplicate document: [1e] In 2015, Rob Bradford and Lou Merloni filled ...
# Skipping duplicate document: [1f] Mike Mutnansky serves as pre- and post-game h...
# Skipping duplicate document: [0a] The atomic mass or relative isotopic mass ref...
# Skipping duplicate document: [0b] The dimensionless standard atomic weight inst...
# Skipping duplicate document: [0c] Atomic mass values are thus commonly reported...
# Skipping duplicate document: [0d] Standard atomic weight is related to atomic m...
# Skipping duplicate document: [0e] It is usually "about" the same value as the a...
# Skipping duplicate document: [3f] However, this number will not be exactly an i...
# Skipping duplicate document: [3g] The heaviest stable atom is lead-208, with a ...
# Skipping duplicate document: [0a] Georgios Papadopoulos (; ; 5 May 1919 – 27 Ju...
# Skipping duplicate document: [0b] He held his dictatorial power until 1973, whe...
# Skipping duplicate document: [1c] Papadopoulos remained in prison, rejecting an...
# Skipping duplicate document: [0a] While the word "algorithm" goes back only to ...
# Skipping duplicate document: [0b] An interesting early case is that of what we ...
# Skipping duplicate document: [0c] In its basic form (namely, as an algorithm fo...
# Skipping duplicate document: [0d] However, in the form that is often used in nu...
# Skipping duplicate document: [0a] Paracetamol poisoning, also known as acetamin...
# Skipping duplicate document: [0b] Most people have few or non-specific symptoms...
# Skipping duplicate document: [0c] This may include feeling tired, abdominal pai...
# Skipping duplicate document: [0d] This is typically followed by a couple of day...
# Skipping duplicate document: [0e] Additional complications may include kidney f...
# Skipping duplicate document: [0f] If death does not occur, people tend to recov...
# Skipping duplicate document: [0g] Without treatment some cases will resolve whi...
# Skipping duplicate document: [0h] Paracetamol poisoning can occur accidentally ...
# Skipping duplicate document: [0i] Risk factors for toxicity include alcoholism,...
# Skipping duplicate document: [0j] Liver damage results not from paracetamol its...
# Skipping duplicate document: [0k] NAPQI decreases the liver's glutathione and d...
# Skipping duplicate document: [0l] Diagnosis is based on the blood level of para...
# Skipping duplicate document: [0m] These values are often plotted on the Rumack-...
# Skipping duplicate document: [0n] Treatment may include activated charcoal if t...
# Skipping duplicate document: [0o] Attempting to force the person to vomit is no...
# Skipping duplicate document: [0p] If there is a potential for toxicity, the ant...
# Skipping duplicate document: [0q] The medication is generally given for at leas...
# Skipping duplicate document: [0r] Psychiatric care may be required following re...
# Skipping duplicate document: [0s] A liver transplant may be required if damage ...
# Skipping duplicate document: [0t] The need for transplant is often based on low...
# Skipping duplicate document: [0u] With early treatment liver failure is rare....
# Skipping duplicate document: [0v] Death occurs in about 0.1% of cases....
# Skipping duplicate document: [0w] Paracetamol poisoning was first described in ...
# Skipping duplicate document: [0x] Rates of poisoning vary significantly between...
# Skipping duplicate document: [0y] In the United States more than 100,000 cases ...
# Skipping duplicate document: [0z] In the United Kingdom it is the medication re...
# Skipping duplicate document: [0aa] Young children are most commonly affected....
# Skipping duplicate document: [0ab] In the United States and the United Kingdom ...
# Skipping duplicate document: [0a] The term “biochemistry” itself is derived fro...
# Skipping duplicate document: [0b] The word is first recorded in English in 1848...
# Skipping duplicate document: [0c] Nevertheless, several sources cite German che...
# Skipping duplicate document: [1d] It was once generally believed that life and ...
# Skipping duplicate document: [1e] Then, in 1828, Friedrich Wöhler published a p...
# Skipping duplicate document: [1f] Since then, biochemistry has advanced, especi...
# Skipping duplicate document: [1g] These techniques allowed for the discovery an...
# Skipping duplicate document: [1h] Philip Randle is well-known for his discovery...
# Skipping duplicate document: [1i] High fat oxidation was responsible for the in...
# Skipping duplicate document: [0a] According to Robert Casey, the transportation...
# Skipping duplicate document: [0b] Developed under the leadership of AMC's Franç...
# Skipping duplicate document: [0c] With the introduction of more luxurious model...
# Skipping duplicate document: [0d] "The advent and immediate success of AMC/Jeep...
# Skipping duplicate document: [0a] On May 19, 2009, Murphy's musical comedy-dram...
# Skipping duplicate document: [0b] He co-created the series with Brad Falchuk an...
# Skipping duplicate document: [0c] In its early seasons, the show was critically...
# Skipping duplicate document: [0d] Murphy won his first Primetime Emmy Award for...
# Skipping duplicate document: [0e] The series concluded in 2015 following its si...
# Skipping duplicate document: [0f] Murphy was one of four executive producers on...
# Skipping duplicate document: [0g] The show featured a group of contestants vyin...
# Skipping duplicate document: [0h] The show was renewed for a second season, whi...
# Skipping duplicate document: [0a] The Iglehart House is an Italianate style hou...
# Skipping duplicate document: [0b] Located at 11118 S. Artesian Avenue, the orig...
# Skipping duplicate document: [0c] Iglehart's daughter Mary, who was born in the...
# Skipping duplicate document: [0d] Iglehart was one of the founders of The Churc...
# Skipping duplicate document: [0e] Due to the space required of a growing family...
# Skipping duplicate document: [0f] It was designated a Chicago Landmark on July ...
# Skipping duplicate document: [0a] The Stirling Smith Art Gallery and Museum – f...
# Skipping duplicate document: [0b] Established by the bequest of artist Thomas S...
# Skipping duplicate document: [0c] It was founded as a gallery of mainly contemp...
# Skipping duplicate document: [0a] Tornadoes have been recorded on all continent...
# Skipping duplicate document: [0b] The United States has the most tornadoes of a...
# Skipping duplicate document: [0c] A large portion of these tornadoes form in an...
# Skipping duplicate document: [0d] Other areas of the world that have frequent t...
# Skipping duplicate document: [2e] Increased westerly flow off the Rockies force...
# Skipping duplicate document: [2f] This unique topography allows for frequent co...
# Skipping duplicate document: [2g] A large portion of these tornadoes form in an...
# Skipping duplicate document: [2h] This area extends into Canada, particularly O...
# Skipping duplicate document: [2i] Tornadoes also occur across northeastern Mexi...
# ...
# Skipping duplicate document: [0c] By 1957, sales were at $20 billion, represent...
# Skipping duplicate document: [0d] Philip Morris easily overcame growing health ...
# Skipping duplicate document: [1e] The advertisements were originally conceived ...
# Skipping duplicate document: [0a] In 2005, France produced 18,450 tonnes of foi...
# Skipping duplicate document: [0b] Total French consumption of foie gras in this...
# Skipping duplicate document: [0c] In 2005, Hungary, the world's second-largest ...
# Skipping duplicate document: [0a] There are two conventions regarding the "stan...
# Skipping duplicate document: [0b] The IUPAC recommended "standard boiling point...
# Skipping duplicate document: [0c] For comparison, on top of Mount Everest, at e...
# Skipping duplicate document: [0d] The Celsius temperature scale was defined unt...
# Skipping duplicate document: [1e] Positive azeotropes are also called "minimum ...
# Skipping duplicate document: [2f] Similarly, increasing the pressure as in a pr...
# Skipping duplicate document: [0a] Royal George Hotel and Ruddle's Building is a...
# Skipping duplicate document: [0b] It was built from to the 1960s....
# Skipping duplicate document: [0c] It is also known as Bush & Commercial Inn, Co...
# Skipping duplicate document: [0d] It was added to the Queensland Heritage Regis...
# Skipping duplicate document: [0a] The Air pollution is the release of chemicals...
# Skipping duplicate document: [0b] Common gaseous pollutants include carbon mono...
# Skipping duplicate document: [0c] Photochemical ozone and smog are created as n...
# Skipping duplicate document: [0d] Particulate matter, or fine dust is character...
# Skipping duplicate document: [0e] The air in Karachi is rapidly polluted by aut...
# Skipping duplicate document: [0f] The two-stroke engines on rickshaws and motor...
# Skipping duplicate document: [0g] The two-stroke engines as well as defective o...
# Skipping duplicate document: [0h] Two-stroke engines as well as defective vehic...
# Skipping duplicate document: [0i] Automobiles operating on compressed natural g...
# Skipping duplicate document: [0a] Recent decades have seen increasing concern o...
# Skipping duplicate document: [0b] Several programs to increase the rates of vot...
# Skipping duplicate document: [0c] However, the "Stanford Social Innovation Revi...
# Skipping duplicate document: [0d] In fact, they argue that "Millennials are tur...
# Skipping duplicate document: [1e] Young people have the lowest turnout, though ...
# Skipping duplicate document: [1f] Ever since 18-year-olds were given the right ...
# Skipping duplicate document: [1g] In 1976, one of the first elections in which ...
# Skipping duplicate document: [1h] In the next election in 1978, youth were unde...
# Skipping duplicate document: [1i] "Seven out of ten young people…did not vote i...
# Skipping duplicate document: [1j] In 1998, out of the 13 percent of eligible yo...
# Skipping duplicate document: [1k] During the competitive presidential race of 2...
# Skipping duplicate document: [1l] Recently, in the 2008 U.S. Presidential elect...
# Skipping duplicate document: [0a] No....
# Skipping duplicate document: [0b] 428 Squadron RCAF was the ninth long-range he...
# Skipping duplicate document: [0c] The squadron was initially assigned to No....
# Skipping duplicate document: [0d] 4 Group RAF....
# Skipping duplicate document: [0e] With the creation of No....
# Skipping duplicate document: [0f] 6 Group RCAF, the squadron was reallocated on...
# Skipping duplicate document: [1g] After only three months, he left 428 Bomber S...
# Skipping duplicate document: [1h] He ended the war as Air Officer Commanding No...
# Skipping duplicate document: [1i] 300 Group RAF (RAF Transport Command) in Aust...
# Skipping duplicate document: [0a] Until the 19th century, a bachelor's degree r...
# Skipping duplicate document: [0b] Vestiges of this system still remain in the a...
# Skipping duplicate document: [0c] BPhil, BCL) as postgraduate awards equivalent...
# Skipping duplicate document: [0d] LLM for the LLB at Cambridge and MSc for the ...
# Skipping duplicate document: [0e] The same historical usage of indicating an un...
# Skipping duplicate document: [1f] These programs prepare graduates for further ...
# Skipping duplicate document: [1g] The program focus may be on the technical or ...
# Skipping duplicate document: [6h] At the undergraduate Honors College of the Un...
# Skipping duplicate document: [6i] candidates must pass oral examinations of a s...
# Skipping duplicate document: [6j] Northwestern University's B.Phil....
# Skipping duplicate document: [6k] degree requires two years of a foreign langua...
# Skipping duplicate document: [6l] The University of Birmingham offers the B.Phi...
# Skipping duplicate document: [6m] as a taught, research-based undergraduate deg...
# Skipping duplicate document: [6n] The University of New Brunswick offers the B....
# Skipping duplicate document: [6o] as a seminar-based degree in interdisciplinar...
# Skipping duplicate document: [6p] St. John's Seminary (Massachusetts) offers th...
# Skipping duplicate document: [6q] degree upon completion of its two-year Pre-Th...
# Skipping duplicate document: [6r] The Technical University of Kenya offers the ...
# Skipping duplicate document: [6s] to those with Higher Diplomas in various subj...
# Skipping duplicate document: [6t] Stellenbosch University offers a B.Phil....
# Skipping duplicate document: [6u] in journalism....
# Skipping duplicate document: [6v] Prospective students must have obtained a rec...
# Skipping duplicate document: [6w] Top-performing applicants are then invited to...
# Skipping duplicate document: [6x] The B.Phil....
# Skipping duplicate document: [6y] is regarded as one of the most sought after a...
# Skipping duplicate document: [0a] The composition of his Fourth Symphony marked...
# Skipping duplicate document: [0b] In fact, this tetralogy was part of an entire...
# Skipping duplicate document: [0c] The composition of his String Quintet and the...
# Skipping duplicate document: [0d] However, the Sixth Symphony has extensive tie...
# Skipping duplicate document: [0e] It has even been dubbed the "Philosophical" s...
# Skipping duplicate document: [1f] The symphony is sometimes referred to as the ...
# Skipping duplicate document: [0a] In Europe, early footballs were made out of a...
# Skipping duplicate document: [0b] Later leather coverings were introduced to al...
# Skipping duplicate document: [0c] However, in 1851, Richard Lindon and William ...
# Skipping duplicate document: [0d] Richard Lindon's wife is said to have died of...
# Skipping duplicate document: [0e] Lindon also won medals for the invention of t...
# Adding data to Milvus:  44%|████▍     | 8/18 [00:09<00:08,  1.13it/s]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0a] No....
# Skipping duplicate document: [0a] The Todd Bertuzzi–Steve Moore incident (also ...
# Skipping duplicate document: [0b] In the first period, Steve Moore fought Vanco...
# Skipping duplicate document: [0c] The Avalanche would go on to build up a large...
# Skipping duplicate document: [0d] Late in the third period, Todd Bertuzzi was s...
# Skipping duplicate document: [0e] After failing to instigate Moore to fight, Be...
# Skipping duplicate document: [0f] Bertuzzi landed on top of him, driving Moore ...
# Skipping duplicate document: [0g] Moore was knocked out and lay motionless for ...
# Skipping duplicate document: [0h] The combination of the hit, fall, and piling-...
# Skipping duplicate document: [0i] The incident ended Moore's professional hocke...
# Skipping duplicate document: [0j] On August 19, 2014, it was reported the civil...
# Adding data to Milvus:  50%|█████     | 9/18 [00:22<00:43,  4.80s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [1f] He has appeared in more films than any other ...
# Adding data to Milvus:  56%|█████▌    | 10/18 [00:36<00:59,  7.44s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [1h] Throughout his life and political career, he ...
# Adding data to Milvus:  61%|██████    | 11/18 [00:49<01:04,  9.28s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0a] Liz Rose (born in Dallas, Texas) is an Americ...
# Skipping duplicate document: [0b] She has co-written twenty of Swift's official...
# Skipping duplicate document: [0a] County Antrim (named after the town of Antrim...
# Skipping duplicate document: [0b] Adjoined to the north-east shore of Lough Nea...
# Skipping duplicate document: [0c] County Antrim has a population density of 203...
# Skipping duplicate document: [0d] It is also one of the thirty-two traditional ...
# Skipping duplicate document: [2g] The building was designed by Henry N. Cobb of...
# Skipping duplicate document: [2h] It is one of the most recognizable buildings ...
# Skipping duplicate document: [0a] "Chim Chim Cher-ee" is a song from "Mary Popp...
# Skipping duplicate document: [0b] It was originally sung by Dick Van Dyke and J...
# Skipping duplicate document: [0c] The song can be heard in the "Mary Poppins" s...
# Adding data to Milvus:  67%|██████▋   | 12/18 [01:02<01:03, 10.57s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [1f] When the Cardinals reopened the team Hall of ...
# Skipping duplicate document: [0a] The 1976 NBA draft was the 30th annual draft ...
# Skipping duplicate document: [0b] The draft was held on June 8, 1976, before th...
# Skipping duplicate document: [0c] In this draft, 18 NBA teams took turns select...
# Skipping duplicate document: [0d] The first two picks in the draft belonged to ...
# Skipping duplicate document: [0e] The Atlanta Hawks won the coin flip and were ...
# Skipping duplicate document: [0f] The Hawks then traded the first pick to the H...
# Skipping duplicate document: [0g] The remaining first-round picks and the subse...
# Skipping duplicate document: [0h] The New York Knicks forfeited their first-rou...
# Skipping duplicate document: [0i] The 76ers, the Golden State Warriors and the ...
# Skipping duplicate document: [0j] A player who had finished his four-year colle...
# Skipping duplicate document: [0k] If a player left college early, he would not ...
# Skipping duplicate document: [0l] Before the draft, 26 college underclassmen we...
# Skipping duplicate document: [0m] 13 of them withdrew before the draft, leaving...
# Skipping duplicate document: [0n] These players had applied and gave evidence o...
# Skipping duplicate document: [0o] The draft consisted of 10 rounds comprising t...
# Skipping duplicate document: [0p] On August 8, 1976, the league also hosted a D...
# Skipping duplicate document: [3e] It also stars Scarlett Johansson, Michael Cai...
# Skipping duplicate document: [3f] The film reunites Nolan with actors Bale and ...
# Skipping duplicate document: [3g] "....
# Skipping duplicate document: [0a] Overview....
# Skipping duplicate document: [0a] Please try again later....
# Skipping duplicate document: [0c] 1....
# Adding data to Milvus:  72%|███████▏  | 13/18 [01:16<00:56, 11.36s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0a] Please try again later....
# Skipping duplicate document: [0a] Overview....
# Skipping duplicate document: [0d] 2....
# Skipping duplicate document: [0a] Making the world better, one answer at a time...
# Skipping duplicate document: [0b] (2000 U.S. Census)....
# Skipping duplicate document: [0f] 3...
# Skipping duplicate document: [1f] ADVERTISEMENT....
# Skipping duplicate document: [0b] (United States)....
# Skipping duplicate document: [0a] Making the world better, one answer at a time...
# Adding data to Milvus:  78%|███████▊  | 14/18 [01:29<00:47, 11.97s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0c] 1....
# Skipping duplicate document: [0a] Save....
# Skipping duplicate document: [0a] [ 2 syll....
# Skipping duplicate document: [0b] (2000 U.S. Census)....
# Skipping duplicate document: [0a] Noun....
# Skipping duplicate document: [0a] Definition....
# Skipping duplicate document: [0a] Yes....
# Skipping duplicate document: [0f] 2....
# Skipping duplicate document: [0a] Definition....
# Skipping duplicate document: [0e] Supplement....
# Skipping duplicate document: [0e] ADVERTISEMENT....
# Skipping duplicate document: [0d] 3....
# Skipping duplicate document: [0a] Save....
# Skipping duplicate document: [0f] A....
# Adding data to Milvus:  83%|████████▎ | 15/18 [01:42<00:37, 12.37s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0b] Source: HR Reported data as of October 2015....
# Skipping duplicate document: [0a] 1....
# Skipping duplicate document: [0a] 1....
# Skipping duplicate document: [0c] 2....
# Skipping duplicate document: [1e] 3....
# Skipping duplicate document: [0a] Canada is unusual among developed countries i...
# Skipping duplicate document: [0b] Canada also has a sizable manufacturing secto...
# Skipping duplicate document: [0a] Noun....
# Skipping duplicate document: [0d] Translations....
# Skipping duplicate document: [0a] Noun....
# Skipping duplicate document: [0b] Source: HR Reported data as of October 2015....
# Skipping duplicate document: [0c] 1  Salary....
# Skipping duplicate document: [0a] Please try again later....
# Skipping duplicate document: [0a] Rating Newest Oldest....
# Skipping duplicate document: [1g] 1....
# Skipping duplicate document: [0a] Causes....
# Skipping duplicate document: [0f] 2....
# Skipping duplicate document: [0a] 6....
# Skipping duplicate document: [1e] 3....
# Skipping duplicate document: [0e] 2....
# Skipping duplicate document: [0d] A....
# Adding data to Milvus:  89%|████████▉ | 16/18 [01:56<00:25, 12.64s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0d] ADVERTISEMENT....
# Skipping duplicate document: [0c] 2....
# Skipping duplicate document: [1e] 3....
# Skipping duplicate document: [1e] !...
# Skipping duplicate document: [0a] Rating Newest Oldest....
# Skipping duplicate document: [2g] 3....
# Skipping duplicate document: [0b] ....
# Skipping duplicate document: [0a] noun....
# Skipping duplicate document: [1d] To estimate costs for your project: 1....
# Skipping duplicate document: [1f] 2....
# Skipping duplicate document: [0a] 6....
# Skipping duplicate document: [0c] 2....
# Skipping duplicate document: [0a] 2....
# Skipping duplicate document: [0f] 2....
# Skipping duplicate document: [0a] Definition....
# Skipping duplicate document: [1g] 4....
# Skipping duplicate document: [0a] Overview....
# Skipping duplicate document: [0a] Report Abuse....
# Skipping duplicate document: [1e] 4....
# Skipping duplicate document: [0a] Report Abuse....
# Skipping duplicate document: [0a] Definition....
# Skipping duplicate document: [0a] Report Abuse....
# Skipping duplicate document: [0a] Overview....
# Skipping duplicate document: [2f] 1...
# Skipping duplicate document: [0a] A....
# Skipping duplicate document: [2g] kids...
# Skipping duplicate document: [2g] 3....
# Adding data to Milvus:  94%|█████████▍| 17/18 [02:09<00:12, 12.81s/it]
# Inserted 2500 records into collection 'ragbench_hhm_v1'.
# Skipping duplicate document: [0c] 1....
# Skipping duplicate document: [0e] 2....
# Skipping duplicate document: [0a] Uses....
# Skipping duplicate document: [1f] ADVERTISEMENT....
# Skipping duplicate document: [0h] ....
# Skipping duplicate document: [0d] 1....
# Skipping duplicate document: [0b] n. 1....
# Skipping duplicate document: [0d] Each salary is associated with a real job pos...
# Skipping duplicate document: [0b] n. 1....
# Skipping duplicate document: [0c] SoulUrge Number: 1....
# Skipping duplicate document: [0e] People with this name have a deep inner desir...
# Skipping duplicate document: [0d] 2....
# Skipping duplicate document: [0h] 3....
# Skipping duplicate document: [0a] In this article....
# Skipping duplicate document: [0a] Definition....
# Adding data to Milvus: 100%|██████████| 18/18 [02:09<00:00,  7.22s/it]
# Inserted 1159 records into collection 'ragbench_hhm_v1'.

# %%
questions = ['When was Rolex founded?', 'How large is the region of Macedonia?', 
             'Where is GMT Games headquartered?', 'What state is directly north of North Carolina?', 
             'When was Brown v. Board of Education?',
             
             'What star of Parks and Recreation appeared in November?', 
             'What is the capacity of the Stadium, other than Kauffman Stadium, designed by Charles Deaton ?', 
             'What was the island, on which Marinelli Glacier is located, formerly known as?', 
             'The American Sweetgum is the hostplant of what kind of bug?', 
             'The name of the Japanese rock band T-Bolan was inspired by the name of an English rock band formed in what year?',
             
             'symptoms of pregnancy before a missed period', 'monoclonal antibodies biology definition', 
             'what is iron sulfate', "who sang one day i'll fly away", 
             'describe the antebellum reform movement period'
            ]

# %% [markdown]
# ## **Retrieve Candidates from DB **##
